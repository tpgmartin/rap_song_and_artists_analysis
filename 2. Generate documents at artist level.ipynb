# %%
import pandas as pd
import re

# %%
# TODO
# * Strip out non spoken text from lyrics i.e. text within square brackets
# * Remove text within round brackets
# * Remove line breaks
# * Lowercase everything
# * Remove commas
# * Removing trailing dashes

# %%
tracks_with_lyrics = pd.read_csv("./data/tracks_with_lyrics_since_2013.csv")

# %%
def get_word_list(track_details):
    
    lyrics = track_details["lyrics"]

    try:
        # remove text between brackets, remove punctuation except for apostraphes
        lyrics = re.sub("([\(\[].*?[\)\]])|([^\w\d'\s]+)", "", lyrics)
        # replace line breaks with whitespace
        lyrics = re.sub("\n", " ", lyrics)
        # lowercase everything
        lyrics = lyrics.lower()
        # covert to list
        word_list = lyrics.split()
    except:
        artist = track_details["artist"]
        album = track_details["album"]
        track = str(track_details["track"])
        print(artist + "," + album + "," + track + ",")
        word_list = []

    return word_list

# %%
tracks_with_lyrics["word_list"] = None

for idx, row in tracks_with_lyrics.iterrows():

    word_list = get_word_list(row)
    tracks_with_lyrics.set_value(idx,'word_list',word_list)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Atmosphere,Fishing Blues,Everything,
# Atmosphere,Southsiders,Kanye West,
# Atmosphere,Southsiders,Idiot,
# Big Sean,Hall Of Fame,Fire,
# Boosie BadAzz,Out My Feelings In My Past,World War 6,
# Boosie BadAzz,BooPac,Webbie I Remember,
# Boosie BadAzz,In My Feelings. ( Goin' Thru It ),Forgive Me Being Lost,
# Boosie BadAzz,Out My Feelings In My Past,Who Finished?,
# Boosie BadAzz,Out My Feelings In My Past,Got It on Me,
# Boosie BadAzz,Out My Feelings In My Past,Choppers n' Gunz (Album Version),
# Boosie BadAzz,BooPac,Wrong Role Model,
# Boosie BadAzz,In My Feelings. ( Goin' Thru It ),Cancer,
# Boosie BadAzz,Bleek Mode: Thug In Peace Lil Bleek,Beautiful Smiles N Cold Hearts,
# Boosie BadAzz,In My Feelings. ( Goin' Thru It ),Warning Signs,
# Boosie BadAzz,Thug Talk,Menace II Society,
# Boosie BadAzz,Bleek Mode: Thug In Peace Lil Bleek,Not My Nigga,
# Boosie BadAzz,BooPac,Cocaine Fever,
# Boosie BadAzz,BooPac,Heartless Hearts,
# Boosie BadAzz,Out My Feelings In My Past,Look At Life Different,
# Boosie BadAzz,Life After Deathrow,Here We Go Again,
# Boosie BadAzz,In My Feelings. ( Goin' Thru It ),I Know They Gone Miss Me,
# Boosie BadAzz,Thug Talk,Thug Talk,
# Boosie BadAzz,Out My Feelings In My Past,Uncle Tone,
# Boosie BadAzz,BooPac,Real Shooter,
# BrockHampton,Saturation III,CINEMA 2,
# BrockHampton,Saturation III,TEAM,
# BrockHampton,Saturation III,STUPID,
# BrockHampton,Saturation III,SISTER / NATION,
# BrockHampton,Saturation III,CINEMA 3,
# BrockHampton,iridescence,WHERE THE CASH AT,
# BrockHampton,Saturation III,ALASKA,
# BrockHampton,iridescence,TONYA,
# BrockHampton,iridescence,SAN MARCOS,
# BrockHampton,iridescence,BERLIN,
# BrockHampton,iridescence,VIVID,
# BrockHampton,Saturation III,STAINS,
# BrockHampton,Saturation III,JOHNNY,
# BrockHampton,Saturation III,CINEMA 1,
# BrockHampton,iridescence,FABRIC,
# BrockHampton,iridescence,J'OUVERT,
# BrockHampton,Saturation III,HOTTIE,
# BrockHampton,iridescence,TAPE,
# BrockHampton,iridescence,HONEY,
# BrockHampton,iridescence,THUG LIFE,
# Cardi B,Gangsta Bitch Music, Vol. 1,BON,
# Cardi B,Gangsta Bitch Music, Vol. 1,Everything,
# Cardi B,Gangsta Bitch Music, Vol. 1,Trick,
# Chief Keef,Finally Rich,Savage,
# Chief Keef,Bang 3,Yes,
# Danny Brown,Atrocity Exhibition,Today,
# Danny Brown,Old,Lonely,
# Danny Brown,Atrocity Exhibition,Lost,
# G-Eazy,These Things Happen,Interlude,
# G-Eazy,The Beautiful & Damned,Legend,
# Gucci Mane,The Return Of East Atlanta Santa,Yet,
# Gucci Mane,The Return Of East Atlanta Santa,I Can't,
# Gucci Mane,The Return Of East Atlanta Santa,Crash,
# Hopsin,Pound Syndrome,My Love,
# Hopsin,Pound Syndrome,FLY,
# Isaiah Rashad,The Sun's Tirade,Park,
# Isaiah Rashad,The Sun's Tirade,AA,
# Jeezy,Seen It All: The Autobiography,Enough,
# Jeezy,Trap Or Die 3,So What,
# Jeezy,Church In These Streets,God,
# Jeezy,Pressure,Respect,
# Kendrick Lamar,To Pimp A Butterfly,​u,
# Kevin Gates,By Any Means 2,Came Up,
# Kevin Gates,By Any Means,Don't Know,
# Lecrae,Church Clothes 3,Deja Vu,
# Lecrae,Anomaly,Fear,
# Lecrae,Church Clothes 3,Forever,
# Lecrae,Gravity,Violence,
# Lecrae,Gravity,I Know,
# Lecrae,Anomaly,Wish,
# Lil Yachty,Lil Boat 2,FLEX,
# Lil Yachty,Nuthin' 2 Prove,Worth It,
# Lil Yachty,Nuthin' 2 Prove,Next Up,
# Logic,Under Pressure,Intro,
# Mac Miller,The Divine Feminine,Stay,
# Machine Gun Kelly,General Admission,Oz.,
# Machine Gun Kelly,General Admission,Life,
# Machine Gun Kelly,General Admission,Everyday,
# Machine Gun Kelly,BINGE,LOCO,
# Mike Stud,These Days,Black Out,
# Mike Stud,Closer,Movie,
# Mike Stud,Relief,Thank You,
# Moneybagg Yo,2 Heartless,Thoughts,
# Moneybagg Yo,Federal 3X,On Me,
# Moneybagg Yo,Federal 3X,Right Now,
# Moneybagg Yo,Federal 3X,Blog,
# Moneybagg Yo,2 Heartless,Scars,
# NF,Perception,Know,
# NF,Perception,Outro,
# NF,Perception,3 A.M.,
# NF,Perception,Dreams,
# NF,Therapy Session,Real,
# Rittz,Top Of The Line,Nostalgia,
# Rittz,Next To Nothing,Blow,
# Rittz,The Life And Times Of Jonny Valiant,All Around The World,
# Russ,There's Really A Wolf,Me You,
# Russ,There's Really A Wolf,MVP,
# Russ,There's Really A Wolf,Scared,
# Starbomb,Starbomb,Intro,
# Starbomb,Starbomb,Outro,
# Swollen Members,Brand New Day,Nemesis,
# Swollen Members,Brand New Day,Power,
# Swollen Members,Beautiful Death Machine,Almost Famous,
# Tech N9ne,Something Else,Something Else Cover,
# Tech N9ne,Something Else,Believe,
# Tech N9ne,The Storm,Wet,
# The Game,The Documentary 2.5,Life,
# The Game,Blood Moon: Year Of The Wolf,F.U.N.,
# The Lacs,Outlaw In Me,Stomp,
# The Lacs,Keep It Redneck,Get Lost,
# The Lacs,Outlaw In Me,Worth It,
# The Lacs,Keep It Redneck,Memory,
# Tory Lanez,I Told You,High,
# Upchurch,King Of Dixie,Tunnel Vision,
# Upchurch,King Of Dixie,Johnny Cash,
# Upchurch,King Of Dixie,Legend,
# Upchurch,King Of Dixie,Conspiracy,
# Wale,SHINE,DNA,
# Wiz Khalifa,Rolling Papers 2,King,
# Wiz Khalifa,Blacc Hollywood,Raw,
# Wiz Khalifa,O.N.I.F.C.,Time,
# Wiz Khalifa,Rolling Papers 2,Ocean,
# YG,Blame It On The Streets (Soundtrack),nan,
# Yo Gotti,The Art Of Hustle,Come Up,
# Yo Gotti,White Friday (CM9),Blah Blah Blah,
# Yo Gotti,I Still Am,Around the World,
# Yo Gotti,I Am,I Am,
# Young Thug,Barter 6,OD,
# Z-Ro,Legendary,I Know,
# Z-Ro,Drankin & Drivin,Hostage,
# Z-Ro,Legendary,Come With Me,
# Z-Ro,Legendary,My Time,
# Z-Ro,Legendary,OG,
# Z-Ro,Drankin & Drivin,My Money,
# Z-Ro,Legendary,I'm Good,
# Z-Ro,Drankin & Drivin,Successful,

# %%
tracks_with_lyrics = tracks_with_lyrics.drop(tracks_with_lyrics[tracks_with_lyrics["lyrics"].isnull()].index)

# %%
tracks_with_missing_lyrics = pd.read_csv("./data/missing_lyrics.csv")

# %%
tracks_with_missing_lyrics["word_list"] = None

for idx, row in tracks_with_missing_lyrics.iterrows():

    word_list = get_word_list(row)
    tracks_with_missing_lyrics.set_value(idx,'word_list',word_list)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
tracks_with_missing_lyrics
# Out:
#             artist                  album      track  \
# 0           Future            BEASTMODE 2  RED LIGHT
# 1   Kendrick Lamar    To Pimp A Butterfly         ​u
# 2      Kevin Gates         By Any Means 2    Came Up
# 3       Lil Yachty             Lil Boat 2       FLEX
# 4       Lil Yachty       Teenage Emotions    No More
# 5     Moneybagg Yo            2 Heartless    Secrets
# 6     Moneybagg Yo             Federal 3X  Right Now
# 7     Moneybagg Yo            2 Heartless   Thoughts
# 8               NF        Therapy Session       Real
# 9               NF             Perception      Outro
# 10              NF             Perception       Know
# 11              NF        Therapy Session    Breathe
# 12              NF             Perception     Dreams
# 13              NF             Perception        Lie
# 14     Post Malone                 Stoney       Cold
# 15            Russ  There's Really A Wolf     Scared
# 16            Russ  There's Really A Wolf     Me You
# 17            Russ  There's Really A Wolf        MVP
# 18     Wiz Khalifa       Rolling Papers 2      Ocean
#
#                                                lyrics  \
# 0   [Intro]\nYeah, nigga, this shit real out here\...
# 1   [Produced by Taz Arnold & Whoarei; Additional ...
# 2   [Chorus]\nYoung nigga hold a rock for the fami...
# 3   [Verse 1]\nAnd you hate when I do this shit, s...
# 4   [Intro]\nHey, Lil Boat\n\n[Chorus]\nI can't ta...
# 5   [Intro]\nNah you crazy, but for real though\nL...
# 6   [Intro]\nI'm counting faces, ducking cases\nI'...
# 7   [Intro]\nFuck you, fuck you, fuck you, you're ...
# 8   [Intro]\nYeah, real music\nAgh! Yo\nJust get i...
# 9   [Verse]\nI'm dedicated, the definition of dedi...
# 10  [Intro]\nYeah\nI wanna know, I wanna know\nI w...
# 11  [Hook]\nBreathe\nBreathe\n\n[Verse 1]\nI grew ...
# 12  [Verse 1]\nYeah, most of my life's full of sad...
# 13  [Chorus]\nI heard you told your friends that I...
# 14  [Intro]\nGood job, First\n\n[Chorus]\nYeah, my...
# 15  [Chorus]\nTake my hand and rock it real slow\n...
# 16  [Intro]\nYeah, yeah, there's a difference\nOh ...
# 17  [Intro]\nYeah\nMake money off of bein' myself\...
# 18  [Intro]\nGot you rolling papers, got you rolli...
#
#                                             word_list
# 0   [yeah, nigga, this, shit, real, out, here, run...
# 1   [loving, you, is, complicated, loving, you, is...
# 2   [young, nigga, hold, a, rock, for, the, family...
# 3   [and, you, hate, when, i, do, this, shit, skat...
# 4   [hey, lil, boat, i, can't, take, no, more, no,...
# 5   [nah, you, crazy, but, for, real, though, like...
# 6   [i'm, counting, faces, ducking, cases, i'm, se...
# 7   [fuck, you, fuck, you, fuck, you, you're, cool...
# 8   [yeah, real, music, agh, yo, just, get, in, th...
# 9   [i'm, dedicated, the, definition, of, dedicati...
# 10  [yeah, i, wanna, know, i, wanna, know, i, wann...
# 11  [breathe, breathe, i, grew, up, in, a, small, ...
# 12  [yeah, most, of, my, life's, full, of, sad, da...
# 13  [i, heard, you, told, your, friends, that, i'm...
# 14  [good, job, first, yeah, my, wrist, so, cold, ...
# 15  [take, my, hand, and, rock, it, real, slow, i,...
# 16  [yeah, yeah, there's, a, difference, oh, yeah,...
# 17  [yeah, make, money, off, of, bein', myself, ge...
# 18  [got, you, rolling, papers, got, you, rolling,...

# %%
tracks_with_lyrics = tracks_with_lyrics.append(tracks_with_missing_lyrics)

# %%
tracks_with_lyrics.sort_values(by=["artist"], inplace=True)

# %%
tracks_with_lyrics.to_csv("./data/complete_tracks_with_lyrics.csv", index=False,)

# %%
if not None:
    print("SFsdff")
# Out:
# SFsdff
