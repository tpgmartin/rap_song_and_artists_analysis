# %%
from ast import literal_eval
from collections import Counter
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
# from nltk.tokenize import TreebankWordTokenizer
import numpy as np
import pandas as pd
# import seaborn as sns
# import sklearn.feature_extraction.text
# from wordcloud import WordCloud

# %%
data = pd.read_csv("./data/complete_tracks_with_lyrics.csv")

# %%
data.head()
# Out:
#          artist           album     track  \
# 0  BROCKHAMPTON     iridescence    WEIGHT
# 1  BROCKHAMPTON     iridescence     VIVID
# 2  BROCKHAMPTON     iridescence      TAPE
# 3  BROCKHAMPTON  Saturation III    STAINS
# 4  BROCKHAMPTON     iridescence  DISTRICT
#
#                                               lyrics  \
# 0  [Verse 1: Kevin Abstact]\nThey split my world ...
# 1  [Intro: Matt Champion]\n"Yo, get—[censored]—tu...
# 2  [Verse 1: Kevin Abstract]\nI can barely rap, I...
# 3  [Verse 1: Ameer Vann]\nI spent like a year and...
# 4  [Intro]\n"I'm Sammy Jo, and my favorite colors...
#
#                                            word_list
# 0  ['they', 'split', 'my', 'world', 'into', 'piec...
# 1  ['yo', 'getcensoredturn', 'that', 'shit', 'ove...
# 2  ['i', 'can', 'barely', 'rap', 'i', 'can', 'bar...
# 3  ['i', 'spent', 'like', 'a', 'year', 'and', 'a'...
# 4  ["i'm", 'sammy', 'jo', 'and', 'my', 'favorite'...

# %%
word_list_by_artist = {}

for artist in data["artist"].unique():
    for idx, row in data[data["artist"] == artist].iterrows():
        if row["artist"] in word_list_by_artist:
            word_list_by_artist[row["artist"]]["word_list"].extend(literal_eval(row["word_list"]))
        else:
            word_list_by_artist[row["artist"]] = {
                "artist": row["artist"],
                "word_list": literal_eval(row["word_list"])
            }

# %%
columns = ["artist", "normalised_word_count", "normalised_unique_word_count", "1st_word", "2nd_word", "3rd_word", "4th_word", "5th_word", "6th_word", "7th_word", "8th_word", "9th_word", "10th_word"]
stats_df = pd.DataFrame(columns=columns)
stats_df

for key, value in word_list_by_artist.items():

    word_list = value["word_list"]
    filtered_words = [word for word in word_list if word not in stopwords.words('english')]

    normalised_word_count = len(filtered_words)
    normalised_unique_word_count = len(set(filtered_words))
    vocab_richness = normalised_unique_word_count / normalised_word_count
    top_10_words = Counter(filtered_words).most_common(10)

    new_row = {
        "artist": key,
        "normalised_word_count": normalised_word_count,
        "normalised_unique_word_count": normalised_unique_word_count,
        "vocab_richness": vocab_richness,
        "1st_word": top_10_words[0][0],
        "2nd_word": top_10_words[1][0],
        "3rd_word": top_10_words[2][0],
        "4th_word": top_10_words[3][0],
        "5th_word": top_10_words[4][0],
        "6th_word": top_10_words[5][0],
        "7th_word": top_10_words[6][0],
        "8th_word": top_10_words[7][0],
        "9th_word": top_10_words[8][0],
        "10th_word": top_10_words[9][0]
    }

    stats_df = stats_df.append(new_row, ignore_index=True)

# %%
stats_df
# Out:
#                         artist normalised_word_count  \
# 0                 BROCKHAMPTON                  4728
# 1                        Drake                  5011
# 2                       Eminem                  7564
# 3                       Future                  5933
# 4                   Gucci Mane                  5258
# 5                      J. Cole                  6003
# 6               Kendrick Lamar                  6836
# 7                  Kevin Gates                  6356
# 8                  Kodak Black                  5632
# 9                 Lil Uzi Vert                  5555
# 10                  Lil Yachty                  4220
# 11                       Migos                  7438
# 12                Moneybagg Yo                  5730
# 13                          NF                  5934
# 14                 Post Malone                  4409
# 15                        Russ                  4584
# 16                 Wiz Khalifa                  4985
# 17  YoungBoy Never Broke Again                  5610
#
#
#    6th_word  7th_word 8th_word 9th_word 10th_word  vocab_richness
# 2        la        go     shit     know     never        0.354178
# 11      big       got       go      i'm     bitch        0.258403
# 6      feel      gon'    black      got   alright        0.337039
# 7       get      know      say     like     nigga        0.281309
# 5      know       got      see    wanna      shit        0.283192
# 13       oh     wanna    ain't      get       got        0.243512
# 3      like       get   niggas     keep     nigga        0.268330
# 12     shit       get     real    nigga    niggas        0.268586
# 8     wanna    'cause     baby     love      shit        0.252841
# 17     shit       got     like    never    niggas        0.234046
# 9       got  diamonds    ain't    can't      girl        0.210441
# 4     ain't     money    bales     back       way        0.285470
# 1    niggas       get     shit    ain't     wanna        0.303333
# 16      get    'cause   niggas     hard       say        0.256770
# 0       got    that's    ain't     tell     can't        0.347293
# 15     back      fuck    ain't     shit      i'll        0.306719
# 14    never     wanna     know     keep     ain't        0.241551
# 10    nigga    harley     yeah     name      back        0.262085

# %%
stats_df.sort_values(by=["vocab_richness"], inplace=True, ascending=False)
stats_df
# Out:
#                         artist normalised_word_count  \
# 2                       Eminem                  7564
# 0                 BROCKHAMPTON                  4728
# 6               Kendrick Lamar                  6836
# 15                        Russ                  4584
# 1                        Drake                  5011
# 4                   Gucci Mane                  5258
# 5                      J. Cole                  6003
# 7                  Kevin Gates                  6356
# 12                Moneybagg Yo                  5730
# 3                       Future                  5933
# 10                  Lil Yachty                  4220
# 11                       Migos                  7438
# 16                 Wiz Khalifa                  4985
# 8                  Kodak Black                  5632
# 13                          NF                  5934
# 14                 Post Malone                  4409
# 17  YoungBoy Never Broke Again                  5610
# 9                 Lil Uzi Vert                  5555
#
#    normalised_unique_word_count 1st_word 2nd_word 3rd_word 4th_word 5th_word  \
# 2                          2679      i'm     like      get     back   'cause
# 0                          1642     head     like      i'm     know      get
# 6                          2304      i'm    nigga     like     know    ain't
# 15                         1406      i'm     yeah      got     like     know
# 1                          1520     like      i'm     know     yeah      got
# 4                          1501      i'm      got    gucci     like    nigga
# 5                          1700      i'm   niggas    count    nigga     like
# 7                          1788      i'm     love      got      one    ain't
# 12                         1539      i'm     like      got    ain't     fuck
# 3                          1592      i'm     know     yeah     fuck      got
# 10                         1106      say     like    bitch      i'm     fuck
# 11                         1922     yeah  culture     gang     like      get
# 16                         1280      i'm    ain't      got     know     like
# 8                          1424      i'm    ain't     like      got    nigga
# 13                         1445      i'm     know     like     yeah     feel
# 14                         1065     yeah      i'm      ooh     like       oh
# 17                         1313      i'm    ain't    bitch    nigga     know
# 9                          1169      i'm     yeah     like     know   loaded
#
#    6th_word  7th_word 8th_word 9th_word 10th_word  vocab_richness
# 2        la        go     shit     know     never        0.354178
# 0       got    that's    ain't     tell     can't        0.347293
# 6      feel      gon'    black      got   alright        0.337039
# 15     back      fuck    ain't     shit      i'll        0.306719
# 1    niggas       get     shit    ain't     wanna        0.303333
# 4     ain't     money    bales     back       way        0.285470
# 5      know       got      see    wanna      shit        0.283192
# 7       get      know      say     like     nigga        0.281309
# 12     shit       get     real    nigga    niggas        0.268586
# 3      like       get   niggas     keep     nigga        0.268330
# 10    nigga    harley     yeah     name      back        0.262085
# 11      big       got       go      i'm     bitch        0.258403
# 16      get    'cause   niggas     hard       say        0.256770
# 8     wanna    'cause     baby     love      shit        0.252841
# 13       oh     wanna    ain't      get       got        0.243512
# 14    never     wanna     know     keep     ain't        0.241551
# 17     shit       got     like    never    niggas        0.234046
# 9       got  diamonds    ain't    can't      girl        0.210441
